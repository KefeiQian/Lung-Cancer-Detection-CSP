# %%
import pickle

# %%
with open("../data/cache/caltech/train_gt", 'rb') as fid:
    train_pickle = pickle.Unpickler(fid, encoding="latin1")
    train_gt = train_pickle.load()

train_gt
# Out:
# [{'bboxes': array([[110, 346, 118, 354]]),
#   'ignoreareas': array([], dtype=float64),
#   'filepath': 'data/caltech/train_3/images/1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492_32.jpg'},
#  {'bboxes': array([[408, 337, 415, 344]]),
#   'ignoreareas': array([], dtype=float64),
#   'filepath': 'data/caltech/train_3/images/1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059_56.jpg'},
#  {'bboxes': array([[426, 285, 450, 309]]),
#   'ignoreareas': array([], dtype=float64),
#   'filepath': 'data/caltech/train_3/images/1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059_68.jpg'},
#  {'bboxes': array([[427, 351, 433, 357]]),
#   'ignoreareas': array([], dtype=float64),
#   'filepath': 'data/caltech/train_3/images/1.3.6.1.4.1.14519.5.2.1.6279.6001.111172165674661221381920536987_186.jpg'},
#  {'bboxes': array([[457, 228, 465, 236]]),
#   'ignoreareas': array([], dtype=float64),
# ...

# %%
with open("../data/cache/caltech/test", 'rb') as fid:
    test_pickle = pickle.Unpickler(fid, encoding="latin1")
    test_cache = test_pickle.load()

test_cache
# Out:
# [{'bboxes': array([[354, 279, 378, 303]]),
#   'ignoreareas': array([], dtype=float64),
#   'filepath': 'data/caltech/test/images/1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408431413578140925249_121.jpg'},
#  {'bboxes': array([[231, 305, 238, 312]]),
#   'ignoreareas': array([], dtype=float64),
#   'filepath': 'data/caltech/test/images/1.3.6.1.4.1.14519.5.2.1.6279.6001.112767175295249119452142211437_57.jpg'},
#  {'bboxes': array([[ 89, 228,  94, 233]]),
#   'ignoreareas': array([], dtype=float64),
#   'filepath': 'data/caltech/test/images/1.3.6.1.4.1.14519.5.2.1.6279.6001.112767175295249119452142211437_63.jpg'},
#  {'bboxes': array([[392, 286, 403, 297]]),
#   'ignoreareas': array([], dtype=float64),
#   'filepath': 'data/caltech/test/images/1.3.6.1.4.1.14519.5.2.1.6279.6001.112767175295249119452142211437_69.jpg'},
#  {'bboxes': array([[130, 233, 137, 240]]),
#   'ignoreareas': array([], dtype=float64),
# ...

# %%
for item in train_gt:
    if "1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877" in item["filepath"]:
        print(item)
# Out:
# {'bboxes': array([[220, 307, 232, 319]]), 'ignoreareas': array([], dtype=float64), 'filepath': 'data/caltech/train_3/images/1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877_194.jpg'}
# {'bboxes': array([[189, 193, 210, 214]]), 'ignoreareas': array([], dtype=float64), 'filepath': 'data/caltech/train_3/images/1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877_199.jpg'}
# {'bboxes': array([[382, 247, 388, 253]]), 'ignoreareas': array([], dtype=float64), 'filepath': 'data/caltech/train_3/images/1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877_202.jpg'}
# {'bboxes': array([[375, 203, 383, 211]]), 'ignoreareas': array([], dtype=float64), 'filepath': 'data/caltech/train_3/images/1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877_204.jpg'}
